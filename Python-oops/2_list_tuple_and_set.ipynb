# %%
l =[1,345,45,"sudh" ,True ,5+7j , 345.456]

# %%
l[5].real
# Out:
# 5.0

# %%
type(l)
# Out:
# list

# %%
l[0]
# Out:
# 1

# %%
l[6]
# Out:
# 345.456

# %%
l[90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_3531/2290771669.py in <cell line: 0>()
# ----> 1 l[90]
#
# IndexError: list index out of range

# %%
l

# %%
l[0:3]

# %%
l[-1]

# %%
l[::-1]

# %%
l[::2]
# Out:
# [1, 45, True, 345.456]

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
s = "maritimeexpertise"

# %%
l+s
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/1140923193.py in <cell line: 0>()
# ----> 1 l+s
#
# TypeError: can only concatenate list (not "str") to list

# %%
list(s) + l

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
type(l[3])
# Out:
# str

# %%
l[3][0:2]
# Out:
# 'su'

# %%
l[4]
# Out:
# True

# %%
str(l[4])[0:2]
# Out:
# 'Tr'

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456]

# %%
l+ 5
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/1933099866.py in <cell line: 0>()
# ----> 1 l+ 5
#
# TypeError: can only concatenate list (not "int") to list

# %%
l1 = [3,4,5]

# %%
l+ l1
# Out:
# [3, 4, 5, 55, [1, 3, 4, 5, 6], 324, 's', 'u', 'd', 'h', 3, 4, 5]

# %%
l1 * 3
# Out:
# [3, 4, 5, 3, 4, 5, 3, 4, 5]

# %%
l
# Out:
# [3, 4, 5, 55, [1, 3, 4, 5, 6], 324, 's', 'u', 'd', 'h']

# %%
len(l)
# Out:
# 10

# %%
l
# Out:
# [3, 4, 5, 55, [1, 3, 4, 5, 6], 324, 's', 'u', 'd', 'h']

# %%
l.append(5)

# %%
l
# Out:
# [3, 4, 5, 55, [1, 3, 4, 5, 6], 324, 's', 'u', 'd', 'h']

# %%
l.append(s)

# %%
s
# Out:
# 'maritimeexpertise'

# %%
l
# Out:
# [1, 345, 45, 'sudh', True, (5+7j), 345.456, 5, 'maritimeexpertise']

# %%
l
# Out:
# [3, 4, 5, 55, [1, 3, 4, 5, 6], 324, 's', 'u', 'd', 'h', 'sudh', [3, 4, 5]]

# %%
l1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/2585568370.py in <cell line: 0>()
# ----> 1 l1
#
# NameError: name 'l1' is not defined

# %%
l.append(l1)

# %%
l
# Out:
# [3,
#  4,
#  5,
#  55,
#  [1, 3, 4, 5, 6],
#  324,
#  's',
#  'u',
#  'd',
#  'h',
#  'sudh',
#  [3, 4, 5],
#  [3, 4, 5]]

# %%
l[-1][1]
# Out:
# 4

# %%
l
# Out:
# [3,
#  4,
#  5,
#  55,
#  [1, 3, 4, 5, 6],
#  324,
#  's',
#  'u',
#  'd',
#  'h',
#  'sudh',
#  [3, 4, 5],
#  [3, 4, 5]]

# %%
l.extend(4)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/2311825727.py in <cell line: 0>()
# ----> 1 l.extend(4)
#
# TypeError: 'int' object is not iterable

# %%
l.extend("sudh")

# %%
l
# Out:
# [3,
#  4,
#  5,
#  55,
#  [1, 3, 4, 5, 6],
#  324,
#  's',
#  'u',
#  'd',
#  'h',
#  'sudh',
#  [3, 4, 5],
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h']

# %%
l.extend([3,4,5])

# %%
l
# Out:
# [3,
#  4,
#  5,
#  55,
#  [1, 3, 4, 5, 6],
#  324,
#  's',
#  'u',
#  'd',
#  'h',
#  'sudh',
#  [3, 4, 5],
#  [3, 4, 5],
#  's',
#  'u',
#  'd',
#  'h',
#  3,
#  4,
#  5]

# %%
l1
# Out:
# [3, 4, 5]

# %%
l1.insert(1,"sudh")

# %%
l1
# Out:
# [3, 'sudh', 'sudh', 4, 5]

# %%
l1.insert(2 , [2,3,4])

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], 'sudh', 4, 5]

# %%
l1.insert(-1 , 45)

# %%
l1
# Out:
# [3, 'sudh', [2, 3, 4], 'sudh', 4, 45, 5]

# %%
l1.insert(0 , 45)

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 'sudh', 4, 45, 5]

# %%
l1.pop()
# Out:
# 5

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 'sudh', 4, 45]

# %%
l1.pop()
# Out:
# 45

# %%
l1
# Out:
# [45, 3, 'sudh', [2, 3, 4], 'sudh', 4]

# %%
l1.pop(3)
# Out:
# [2, 3, 4]

# %%
l1
# Out:
# [45, 3, 'sudh', 'sudh', 4]

# %%
l1
# Out:
# [45, 3, 'sudh', 'sudh', 4]

# %%
l1.remove(3)

# %%
l1
# Out:
# [45, 'sudh', 'sudh', 4]

# %%
l1.remove(234)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_3531/2189347925.py in <cell line: 0>()
# ----> 1 l1.remove(234)
#
# ValueError: list.remove(x): x not in list

# %%
l1[2].remove(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_3531/2816361098.py in <cell line: 0>()
# ----> 1 l1[2].remove(3)
#
# AttributeError: 'str' object has no attribute 'remove'

# %%
l1
# Out:
# [45, 'sudh', 'sudh', 4]

# %%
l1.append(4)

# %%
l1
# Out:
# [45, 'sudh', 'sudh', 4, 4]

# %%
l1.remove(4)

# %%
l1
# Out:
# [45, 'sudh', 'sudh', 4]

# %%
l1
# Out:
# [45, 'sudh', 'sudh', 4]

# %%
l1 = l1[::-1]

# %%
l1.reverse()

# %%
l1
# Out:
# [45, 'sudh', 'sudh', 4]

# %%
l1
# Out:
# [45, 'sudh', 'sudh', 4]

# %%
l1.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/2406146923.py in <cell line: 0>()
# ----> 1 l1.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l2 = [45,23,90,0,3,4,5,6,7,8,9]

# %%
l2.sort()

# %%
l2
# Out:
# [0, 3, 4, 5, 6, 7, 8, 9, 23, 45, 90]

# %%
l2
# Out:
# [0, 3, 4, 5, 6, 7, 8, 9, 23, 45, 90]

# %%
l3 = [34,"sudh",45,12,"kumar"]

# %%
l3.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/805862314.py in <cell line: 0>()
# ----> 1 l3.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l4 = ["sudh" , "kumar" , "rohit" , "data science"]

# %%
l4.sort(reverse=True)

# %%
l4
# Out:
# ['sudh', 'rohit', 'kumar', 'data science']

# %%
l4
# Out:
# ['sudh', 'rohit', 'kumar', 'data science']

# %%
l4.index("sudh")
# Out:
# 0

# %%
l4.count("sudh")
# Out:
# 1

# %%
s= "sudh"

# %%
l5 = [3,4,5,6]

# %%
s[0] = 'a'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/2149782055.py in <cell line: 0>()
# ----> 1 s[0] = 'a'
#
# TypeError: 'str' object does not support item assignment

# %%
l5[0] = 30

# %%
l5
# Out:
# [30, 4, 5, 6]

# %%
s
# Out:
# 'sudh'

# %%
s.replace('s' , 'a')
# Out:
# 'audh'

# %%
s
# Out:
# 'sudh'

# %%
t = (2,3,4,5,"sudh" , 45.56, False , 45+457j , [3,4,5] )

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
type(t)
# Out:
# tuple

# %%
len(t)
# Out:
# 9

# %%
t[0]
# Out:
# 2

# %%
t[-1]
# Out:
# [3, 4, 5]

# %%
t[::-1]
# Out:
# ([3, 4, 5], (45+457j), False, 45.56, 'sudh', 5, 4, 3, 2)

# %%
l4
# Out:
# ['sudh', 'rohit', 'kumar', 'data science']

# %%
l4[0] = 23424

# %%
l4
# Out:
# [23424, 'rohit', 'kumar', 'data science']

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
t[0] = "sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/556051525.py in <cell line: 0>()
# ----> 1 t[0] = "sudh"
#
# TypeError: 'tuple' object does not support item assignment

# %%
t[::-1]
# Out:
# ([3, 4, 5], (45+457j), False, 45.56, 'sudh', 5, 4, 3, 2)

# %%
t.count(50)
# Out:
# 0

# %%
t.index(False)
# Out:
# 6

# %%
t
# Out:
# (2, 3, 4, 5, 'sudh', 45.56, False, (45+457j), [3, 4, 5])

# %%
s1 = {}

# %%
type(s1)
# Out:
# dict

# %%
s2 = {2,3,4,55,6}

# %%
type(s2)
# Out:
# set

# %%
s3 = {324,456,456, "sudh" , 45+45j ,34.465 , (3,4,5)}

# %%
s3
# Out:
# {(3, 4, 5), (45+45j), 324, 34.465, 456, 'sudh'}

# %%
s4 = {2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3, 'Sudh', 'sudh'}

# %%
s4
# Out:
# {1, 2, 3, 4, 5, 6, 'Sudh', 'sudh'}

# %%
l6 = [2,3,4,5,6,2,2,3,4,5,2,3,1,2,3,4,5,6,1,2,2,3, 'Sudh', 'sudh']

# %%
l6 = list(set(l6))

# %%
l6
# Out:
# [1, 2, 3, 4, 5, 6, 'Sudh', 'sudh']

# %%
s5 = {234,45,23,12,567,45,2,789,234,"abc", 456,342,23}

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 45, 456, 567, 789, 'abc'}

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 45, 456, 567, 789, 'abc'}

# %%
s5[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/4103576207.py in <cell line: 0>()
# ----> 1 s5[0]
#
# TypeError: 'set' object is not subscriptable

# %%
s5[::-1]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/182782020.py in <cell line: 0>()
# ----> 1 s5[::-1]
#
# TypeError: 'set' object is not subscriptable

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 45, 456, 567, 789, 'abc'}

# %%
s5.add(4)

# %%
s5
# Out:
# {12, 2, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
s5.remove(2)

# %%
s5
# Out:
# {12, 23, 234, 342, 4, 45, 456, 567, 789, 'abc'}

# %%
l4
# Out:
# [23424, 'rohit', 'kumar', 'data science']

# %%
l5
# Out:
# [30, 4, 5, 6]

# %%
l5.append(l4)

# %%
l4 + "sudh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_3531/1336612540.py in <cell line: 0>()
# ----> 1 l4 + "sudh"
#
# TypeError: can only concatenate list (not "str") to list

# %%
l5
# Out:
# [30, 4, 5, 6, [23424, 'rohit', 'kumar', 'data science']]

# %%
s = {1,2,3,1,2,3,4,5,5}

# %%
s
# Out:
# {1, 2, 3, 4, 5}

# %%
s1 ={34,45665,45645,65,664,23,1,1,23,43,4}

# %%
s1
# Out:
# {1, 4, 23, 34, 43, 65, 664, 45645, 45665}

# %%
l = [3,4,5,6,6,6]

# %%
l.insert(-1 , "jay")

# %%
l
# Out:
# [3, 4, 5, 6, 6, 'jay', 6]

# %%
l3=["q",'a','y','z','3','4']

# %%
l3.sort()

# %%
l3
# Out:
# ['3', '4', 'a', 'q', 'y', 'z']

# %%
s = "sudh"
l
# Out:
# [3, 4, 5, 6, 6, 'jay', 6]

# %%
l.insert(3,list(s))

# %%
l
# Out:
# [3, 4, 5, ['s', 'u', 'd', 'h'], 6, 6, 'jay', 6]

# %%
l = [3,4,5,55, [1,3,4,5,6]]

# %%
l4
# Out:
# [23424, 'pwskills', 'kumar', 'data science']

# %%
l4.extend(l)

# %%
l4
# Out:
# [23424, 'pwskills', 'kumar', 'data science', 3, 4, 5, 55, [1, 3, 4, 5, 6]]

# %%
l4[2:5]
# Out:
# ['kumar', 'data science', 3]

# %%
m = "pwskills"

# %%
m[::9999]
# Out:
# 'p'

# %%
l
# Out:
# [3, 4, 5, 55, [1, 3, 4, 5, 6]]

# %%
l.append(324)

# %%
l
# Out:
# [3, 4, 5, 55, [1, 3, 4, 5, 6], 324]

# %%
l.extend("sudh")

# %%
l
# Out:
# [3, 4, 5, 55, [1, 3, 4, 5, 6], 324, 's', 'u', 'd', 'h']
