# %%
d = {}

# %%
type(d)
# Out:
# dict

# %%
d1 = {'key' : "sudh"}

# %%
d1
# Out:
# {'key': 'sudh'}

# %%
d2 = {'name' : "sudhanshu" , "email" : "ss@gmail.com", "number" : 334534}

# %%
d2
# Out:
# {'name': 'sudhanshu', 'email': 'ss@gmail.com', 'number': 334534}

# %%
d3 = {234 : "sudh" , '_wer' : "kumar",True :24234}

# %%
d3
# Out:
# {234: 'sudh', '_wer': 'kumar', True: 24234}

# %%
d3[234]
# Out:
# 'sudh'

# %%
d3[True]
# Out:
# 24234

# %%
d3[1]
# Out:
# 24234

# %%
d4 = {'name':"sudh" , 'mail_id' :"ss@gmail.com" ,"name":"sudhanshu"}

# %%
d4['name']
# Out:
# 'sudhanshu'

# %%
d5 ={"company" : "pwskills" , "course" :["web dev" , "data science " , "java with dsa system design"]}

# %%
d5
# Out:
# {'company': 'pwskills',
#  'course': ['web dev', 'data science ', 'java with dsa system design']}

# %%
d5['course']
# Out:
# ['web dev', 'data science ', 'java with dsa system design']

# %%
d5['course'][2]
# Out:
# 'java with dsa system design'

# %%
d6 = {"number" : [2,34,3,34,34],"assignment":(1,2,3,4,5,6) , "launch_date":{28,12,14} ,"class_time":{"web_dev": 8 , "Data science masters" : 8 , "java with dsa and system design":7}}

# %%
d6
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7}}

# %%
d6['class_time']['java with dsa and system design']
# Out:
# 7

# %%
d6
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7}}

# %%
d6['mentor'] = ["sudhanshu","krish","anurag" , "hayder"]

# %%
d6
# Out:
# {'number': [2, 34, 3, 34, 34],
#  'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7},
#  'mentor': ['sudhanshu', 'krish', 'anurag', 'hayder']}

# %%
del d6['number']

# %%
d6
# Out:
# {'assignment': (1, 2, 3, 4, 5, 6),
#  'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7},
#  'mentor': ['sudhanshu', 'krish', 'anurag', 'hayder']}

# %%
list(d6.keys())
# Out:
# ['assignment', 'launch_date', 'class_time', 'mentor']

# %%
list(d6.values())
# Out:
# [(1, 2, 3, 4, 5, 6),
#  {12, 14, 28},
#  {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7},
#  ['sudhanshu', 'krish', 'anurag', 'hayder']]

# %%
list(d6.items())
# Out:
# [('assignment', (1, 2, 3, 4, 5, 6)),
#  ('launch_date', {12, 14, 28}),
#  ('class_time',
#   {'web_dev': 8,
#    'Data science masters': 8,
#    'java with dsa and system design': 7}),
#  ('mentor', ['sudhanshu', 'krish', 'anurag', 'hayder'])]

# %%
d6.pop('assignment')
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
d6
# Out:
# {'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7},
#  'mentor': ['sudhanshu', 'krish', 'anurag', 'hayder']}

# %%
d6.pop()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6127/150383695.py in <cell line: 0>()
# ----> 1 d6.pop()
#
# TypeError: pop expected at least 1 argument, got 0

# %%
marks = int(input("enter your marks "))
if marks >= 80:
    print("you will be a part of A0 batch")
elif marks >= 60 and marks< 80:
    print("you will be a part of A1 batch")
elif marks >= 40 and marks < 60 :
    print("you will be a part of A2 batch ")
else :
    print("you will be a part of A3 batch ")
# Out:
# enter your marks 80
# you will be a part of A0 batch

# %%
10 >= 80
# Out:
# False

# %%
marks = int(input("enter your marks "))
# Out:
# enter your marks 56

# %%
marks
# Out:
# 56

# %%
type(marks)
# Out:
# int

# %%
price = int(input("enter price " ))
if price > 1000:
    print("i will not purchase")
else :
    print("i will purchase")
# Out:
# enter price 1032
# i will not purchase

# %%
price = int(input("enter price " ))
if price > 1000:
    print("i will not purchase")
    if price >5000:
        print("this is too much ")
    elif price < 2000 :
        print("its ok")
elif price < 1000 or price > 500 :
    print("i will purchase")
else :
    print("not interested ")
# Out:
# enter price 36
# i will purchase

# %%
l = [1,2,3,3,4,5,6,7,8]

# %%
l[0] +1
# Out:
# 2

# %%
l1 = []

# %%
l1.append(l[0] +1)

# %%
l1
# Out:
# [2]

# %%
l = [1,2,3,3,4,5,6,7,8]

# %%
l1 = []
for i in l :
    l1.append(i+1)
    print(i+1)
l1
# Out:
# 2
# 3
# 4
# 4
# 5
# 6
# 7
# 8
# 9
# [2, 3, 4, 4, 5, 6, 7, 8, 9]

# %%
l
# Out:
# [1, 2, 3, 3, 4, 5, 6, 7, 8]

# %%
l = ["sudh" , "kumar" , "skills" , "course"]

# %%
l1 = []
for i in l :
    print(i)
    l1.append(i.upper())
# Out:
# sudh
# kumar
# skills
# course

# %%
l1
# Out:
# ['SUDH', 'KUMAR', 'SKILLS', 'COURSE']

# %%
l = [1,2,3,4,4,"sudh" , "kmumar" , 324,34.456,"abc"]

# %%
l1_num = []
l2_str = []
for i in l :
    if type(i) == int or type(i) == float :
        l1_num.append(i)
    else :
        l2_str.append(i)

# %%
l1_num
# Out:
# [1, 2, 3, 4, 4, 324, 34.456]

# %%
l2_str
# Out:
# ['sudh', 'kmumar', 'abc']

# %%
100+ sample
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_6127/157379921.py in <cell line: 0>()
# ----> 1 100+ sample
#
# NameError: name 'sample' is not defined

# %%
[] - list
() - tuple
{} - with flat element set
{} - with key value pair dict
# Out:
#   File "/tmp/ipykernel_6127/553105698.py", line 3
#     {} - with flat element set
#          ^
# SyntaxError: invalid syntax

# %%
t = (True,4,5,6)

# %%
len(t)
# Out:
# 4

# %%
t.count(True)
# Out:
# 1

# %%
s2 = (1,4,7.7,"class",True)

# %%
s2.count(True)
# Out:
# 2

# %%
marks = 67
if marks >= 80 :
    print("you will be part of A0 batch")
elif marks >= 60 and marks < 80 :
    print("you will be part of A1 batch")
elif marks >= 40 and marks < 60 :
    print("you will be part of A2 batch")
else :
    print("you will be part of A3 batch")
# Out:
# you will be part of A1 batch

# %%
marks = 70
if marks >= 80 :
    print("you will be a part of A0 batch")
if marks >= 60 and  marks <80 :
    print("you will be a part of A1 batch")
elif marks >= 40 and marks < 60 :
    print("you will be a part of A2 batch")
else :
    print("you will be a part of A3 batch")

# %% [markdown]
# sdfas ff fsdfas dasdfasdf asdasdfasdf as
# asdfas
# fasd
# fs
# f
# asf
# asdf
# asdf
# asdf
# sdf
# asdf
# sf
# sdf
# asf
# sd
# fasd
# fasd

# %%
marks = int(input("enter your marks"))

if marks > 100 :
    print("this is not a valid marks" )
else :
    if marks >= 80 :
        print("you will be part of A0 batch")
    elif marks >= 60 and marks < 80 :
        print("you will be part of A1 batch")
    elif marks >= 40 and marks < 60 :
        print("you will be part of A2 batch")
    else :
        print("you will be part of A3 batch")

# %%
s = "munna"

# %%
s[0] = 1

# %%
l = [1,2,3,45]

# %%
l[0] = 100

# %%
l

# %%
l2 = []
for i in l :
    l2.append(i+1)
    print(i+1)
l2
# Out:
# 2
# 3
# 4
# 5
# 5
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_6127/1355588204.py in <cell line: 0>()
#       1 l2 = []
#       2 for i in l :
# ----> 3     l2.append(i+1)
#       4     print(i+1)
#       5 l2
#
# TypeError: can only concatenate str (not "int") to str

# %%
l2 = []
for i in l1 :
    l2.append(i+1)
    print(i+1)
l2

# %%
for ak in "akshat":
    print(ak)
# Out:
# a
# k
# s
# h
# a
# t

# %%
dict1 = {'a': 'akshat', 'b': 'bhuvan', 'c': 'chandan'}

keys = []
values = []
for item in dict1.items():
    keys.append(item[0]), values.append(item[1])

print("keys : ", keys)
print("values : ", values)
# Out:
# keys :  ['a', 'b', 'c']
# values :  ['akshat', 'bhuvan', 'chandan']

# %%
d6
# Out:
# {'launch_date': {12, 14, 28},
#  'class_time': {'web_dev': 8,
#   'Data science masters': 8,
#   'java with dsa and system design': 7},
#  'mentor': ['sudhanshu', 'krish', 'anurag', 'hayder']}

# %%
d6.fromkeys([3,4,5,6])
# Out:
# {3: None, 4: None, 5: None, 6: None}
