# %%
1+1
# Out:
# 2

# %%
5*5
# Out:
# 25

# %%
a = 10

# %%
a
# Out:
# 10

# %%
a
# Out:
# 10

# %%
sudh = 20

# %%
sudh
# Out:
# 20

# %%
a+sudh
# Out:
# 30

# %%
type(a)
# Out:
# int

# %%
type(sudh)
# Out:
# int

# %%
b = 2.09

# %%
type(b)
# Out:
# float

# %%
c = 45.23345

# %%
type(c)
# Out:
# float

# %%
d = "surya"

# %%
type(d)
# Out:
# str

# %%
e = 'this is my first tech class'

# %%
type(e)
# Out:
# str

# %%
n = True

# %%
type(n)
# Out:
# bool

# %%
m = False

# %%
type(m)
# Out:
# bool

# %%
n+m
# Out:
# 1

# %%
True * True
# Out:
# 1

# %%
True * False
# Out:
# 0

# %%
True / False
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_552/2917913318.py in <cell line: 0>()
# ----> 1 True / False
#
# ZeroDivisionError: division by zero

# %%
1 /0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# /tmp/ipykernel_552/2116722390.py in <cell line: 0>()
# ----> 1 1 /0
#
# ZeroDivisionError: division by zero

# %%
sudh = 5 + 8j

# %%
type(v)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_552/2020661051.py in <cell line: 0>()
# ----> 1 type(v)
#
# NameError: name 'v' is not defined

# %%
sudh.real
# Out:
# 5.0

# %%
sudh.imag
# Out:
# 8.0

# %%
sudh
# Out:
# (5+8j)

# %%
print("my name is surya")
# Out:
# my name is surya

# %%
print(a)
# Out:
# 10

# %%
print(sudh)
# Out:
# (5+8j)

# %%
s = "SRMCEM"

# %%
type(s)
# Out:
# str

# %%
s[0]
# Out:
# 'S'

# %%
s[2]
# Out:
# 'M'

# %%
s[3]
# Out:
# 'C'

# %%
s[-1]
# Out:
# 'M'

# %%
s[-5]
# Out:
# 'R'

# %%
s[0:3]
# Out:
# 'SRM'

# %%
s[0:2]
# Out:
# 'SR'

# %%
s[0:4]
# Out:
# 'SRMC'

# %%
s[0:8:2]
# Out:
# 'SME'

# %%
s[0:4:1]
# Out:
# 'SRMC'

# %%
s[::2]
# Out:
# 'SME'

# %%
s[0::2]
# Out:
# 'SME'

# %%
s[2::2]
# Out:
# 'ME'

# %%
s[2::1]
# Out:
# 'MCEM'

# %%
s[::-1]
# Out:
# 'MECMRS'

# %%
s
# Out:
# 'SRMCEM'

# %%
s[2:7:-1]
# Out:
# ''

# %%
s[8:0]
# Out:
# ''

# %%
s[8::-1]
# Out:
# 'MECMRS'

# %%
s[-2 : -8 : -1]
# Out:
# 'ECMRS'

# %%
s[-2 : : -1]
# Out:
# 'ECMRS'

# %%
s[::-1]
# Out:
# 'MECMRS'

# %%
s[::]
# Out:
# 'SRMCEM'

# %%
s[:-90:]
# Out:
# ''

# %%
s[90]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /tmp/ipykernel_552/3290760013.py in <cell line: 0>()
# ----> 1 s[90]
#
# IndexError: string index out of range

# %%
s[:-90000:-1]
# Out:
# 'MECMRS'

# %%
c = 200

# %%
s1 = "this is my string class"

# %%
len(s1)
# Out:
# 23

# %%
s1.find('s')
# Out:
# 3

# %%
s1.find('i')
# Out:
# 2

# %%
s1.find("is")
# Out:
# 2

# %%
#this is a code to find a charecterd of sub string in string
s1.find("iS")
# Out:
# -1

# %%
s1.count('s')
# Out:
# 5

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.count("st")
# Out:
# 1

# %%
s1.count('z')
# Out:
# 0

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.upper()
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s2 = 'THIS IS MY STRING CLASS'

# %%
s2
# Out:
# 'THIS IS MY STRING CLASS'

# %%
s2.lower()
# Out:
# 'this is my string class'

# %%
s1
# Out:
# 'this is my string class'

# %%
s1.title()
# Out:
# 'This Is My String Class'

# %%
s1.capitalize()
# Out:
# 'This is my string class'

# %%
s
# Out:
# 'SRMCEM'

# %%
s + 1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_552/3893389454.py in <cell line: 0>()
# ----> 1 s + 1
#
# TypeError: can only concatenate str (not "int") to str

# %%
s + " sudh"

# %%
s + '1'

# %%
s+ str(1)
# Out:
# 'SRMCEM1'

# %%
s * 3
# Out:
# 'SRMCEMSRMCEMSRMCEM'

# %%
'sudh' *4
# Out:
# 'sudhsudhsudhsudh'

# %%
"sudh" / 4
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_552/1860089750.py in <cell line: 0>()
# ----> 1 "sudh" / 4
#
# TypeError: unsupported operand type(s) for /: 'str' and 'int'

# %%
"don't do copy and paste in my class"
# Out:
# "don't do copy and paste in my class"

# %%
'don"t do copy and paste in my class'
# Out:
# 'don"t do copy and paste in my class'

# %%
s3 = """This is my first class for programming
i have leant variable declaration , data type , string , int , boolean , complex number
i have seen some example of string slicing and indexing
i have gone though some of the string inbuilt function
apart from that i am trying to practice in my system
but some of us in our calss are not executing code and still they are answering which is bad """

# %%
s3
# Out:
# 'This is my first class for programming\ni have leant variable declaration , data type , string , int , boolean , complex number\ni have seen some example of string slicing and indexing\ni have gone though some of the string inbuilt function\napart from that i am trying to practice in my system\nbut some of us in our calss are not executing code and still they are answering which is bad '

# %%
s
# Out:
# 'SRMCEM'

# %%
s[::-1]
# Out:
# 'MECMRS'

# %%
s[-8::-1].upper()
# Out:
# ''

# %%
s = "rohan"

# %%
s
# Out:
# 'rohan'

# %%
print(s)
# Out:
# rohan

# %%
s[-2::-1]
# Out:
# 'ahor'

# %%
s = "edutechcompany"

# %%
s[-2::-1]
# Out:
# 'napmochcetude'

# %%
s4= """Iam praharshitha
im in second year
i want to learn python"""

# %%
s4
# Out:
# 'Iam praharshitha\nim in second year\ni want to learn python'

# %%
s[:-8:-1]
# Out:
# 'ynapmoc'

# %%
s
# Out:
# 'edutechcompany'

# %%
s * 3
# Out:
# 'edutechcompanyedutechcompanyedutechcompany'

# %%
s = "sonamsingh "

# %%
s*3
# Out:
# 'sonamsingh sonamsingh sonamsingh '

# %%
a = 1

# %%
b = 3
c = 5

# %%
s
# Out:
# 'sonamsingh '

# %%
s = 'myskill'

# %%
s[-2::-1]
# Out:
# 'liksym'

# %%
# jkfhsajasf
# fasdfhiasfhd
# ihasdufh
# iuhasdfias
# hoasdofasf
# hiuohasdofs
# hlohasfdsa

# %%
s = "mahadev"

# %%
s[2:3:1]
# Out:
# 'h'

# %%
a = 10

# %%
a
# Out:
# 10
