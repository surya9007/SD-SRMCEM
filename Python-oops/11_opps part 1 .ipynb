# %% [markdown]
# "Oops" stands for Object-Oriented Programming System

# %%
a = 1

# %%
print(type(a))
# Out:
# <class 'int'>

# %%
print(type("skills"))
# Out:
# <class 'str'>

# %%
class test :
    pass

# %%
a = test()

# %%
type(a)
# Out:
# __main__.test

# %%
print(type(a))
# Out:
# <class '__main__.test'>

# %%
class skills :

    def welcome_msg(self):
        print("welcome to skills")

# %%
rohan = skills()

# %%
print(type(rohan))
# Out:
# <class '__main__.skills'>

# %%
rohan.welcome_msg()
# Out:
# welcome to skills

# %%
gaurav = skills()

# %%
gaurav.welcome_msg()
# Out:
# welcome to skills

# %%
class skills1 :

    def __init__(self ,phone_number , email_id , student_id ):
        self.phone_number = phone_number
        self.email_id = email_id
        self.student_id = student_id

    def return_student_deetials(self) :
        return self.student_id ,self.phone_number ,self.email_id

# %%
rohan = skills1(7766554466, "rohan@gmail.com" , 101)

# %%
rohan.phone_number
# Out:
# 7766554466

# %%
rohan.email_id
# Out:
# 'rohan@gmail.com'

# %%
rohan.return_student_deetials()
# Out:
# (101, 7766554466, 'rohan@gmail.com')

# %%
gaurav = skills1(98797867678, "gaurav@gmail.com" , 102)

# %%
gaurav.return_student_deetials()
# Out:
# (102, 98797867678, 'gaurav@gmail.com')

# %%
class skills2 :

    def __init__(self ,phone_number , email_id , student_id ):
        self.phone_number1 = phone_number
        self.email_id1 = email_id
        self.student_id1 = student_id

    def return_student_deetials(self) :
        return self.student_id1 ,self.phone_number1 ,self.email_id1

# %%
sudha = skills2(999954355, "sudh@gmail.com" , 102)

# %%
sudha.phone_number1
# Out:
# 999954355

# %%
sudha.email_id1
# Out:
# 'sudh@gmail.com'

# %%
sudha.return_student_deetials()
# Out:
# (102, 999954355, 'sudh@gmail.com')

# %%
class skills2 :

    def __init__(sudh ,phone_number , email_id , student_id ):
        sudh.phone_number1 = phone_number
        sudh.email_id1 = email_id
        sudh.student_id1 = student_id

    def return_student_deetials(sudh) :
        return sudh.student_id1 ,sudh.phone_number1 ,sudh.email_id1

# %%
rohan = skills2(345365, "rohan@gmail.com" , 324)

# %%
rohan.phone_number1
# Out:
# 345365
